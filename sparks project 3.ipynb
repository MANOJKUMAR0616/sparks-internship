# %% [markdown]
# # GRIP: The Sparks Foundation

# %% [markdown]
# # Data Science and Business Analytics Intern

# %% [markdown]
# # Task 2: Prediction using Decision Tree Algorithm

# %% [markdown]
# # Author: MANOJKUMAR

# %%
#importing the libraries
import pandas as pd
from sklearn.datasets import load_iris

# %%
#load the dataset
iris = load_iris()

# %%
#preparing the target variable
x = iris.data
y = iris.target

# %%
#split the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 44)

# %%
#training the model
from sklearn.tree import DecisionTreeClassifier
data = DecisionTreeClassifier()
data.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # visualizing the decision tree

# %%
#install the modules required
# !pip install pydotplus

# %%
pip install graphviz

# %%
#importing the libraries
from io import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus

# %%
#generate graph of the decision tree
dataset = StringIO()
export_graphviz(data,out_file=dataset,feature_names=iris.feature_names,class_names=iris.target_names,filled=True,rounded=True,special_characters=True)
graph = pydotplus.graph_from_dot_data(dataset.getvalue())
Image(graph.create_png())
